# %%
# Leonardo Azzi, Soluzione v1:
# FINAL SOLUTION

def decoder(test):
    # Remove brackets
    test = test.replace('{', '').replace('}', '')

    if test == "":
        return []
    
    matrix = {}
    cursor_index = [0, 0]
    
    # Ignore consecutive '^' commands at the beginning
    while test and test[0] == '^':
        test = test[1:]
        
    for i in test:
        if i == '_':
            cursor_index[0] += 1
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1])
            #Se necessario, implementare un cap massimo di "profondità" (usa min(max_depth, cursor_index[0] + 1))
        elif i == '^':
            cursor_index[0] = max(0, cursor_index[0] - 1)
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1])
        elif i == '>':
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1] + 1)
        elif i == '<':
            cursor_index[1] = max(0, cursor_index[1] - 1)
        elif i.isdigit():
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            matrix[cursor_index[0]].insert(cursor_index[1], int(i))
            cursor_index[1] += 1
    result = []
    
    try:
        matrix[0] = matrix.get(0, [])
    except:
        matrix[0] = []
        
    for n in range(len(matrix)):
        result.append(matrix.get(n, []))
    return result

# Dizionario[test] = risultato atteso
small_test_list = {
            r"{^}58" : []
            # r"4{_}{<}7{^}{_}{>}4{^}44{_}21297497{_}95578{<}{^}{_}9{>}{^}{<}68" : [[4,4,4],[7,4,2,1,6,8,2,9,7,4,9,7],[9,5,5,7,8,9]],
            # r"{_}{>}{>}{^}{_}{>}{^}{_}{^}{_}{>}{>}{>}{^}{_}{<}{>}{<}{^}{>}{^}{_}{<}{_}{_}{<}{^}{<}{>}{<}{<}{<}{>}{>}{<}{>}{_}{>}{<}{^}{>}{_}{<}{_}{>}{>}{^}{_}{<}{<}{_}{_}{<}" : []
            # r"2618{_}97{^}{<}4552" : [[2,6,1,4,5,5,2,8],[9,7]],
            # r"1{>}2{_}3{>}4{<}5{>}6{<}7{>}8{<}9" : [[1,2],[3,5,4,7,6,9,8]],
            # r"1{>}23{_}4{>}56{_}7{>}89" : [[1, 2, 3], [4, 5, 6], [7, 8, 9]],
            # r"1{_}23{^}4{_}56{^}7{_}89" : [[1, 4, 7], [2, 3, 5, 8, 9, 6]],
            # r"1{>}2{>}3{<}{_}4{>}5{>}6{<}{_}7{>}8{>}9" : [[1, 2, 3], [4, 5, 6], [7, 8, 9]],
            # r"{>}78{_}49{<}{^}{>}2{_}{_}789879626{<}7{>}{_}{<}{<}67581332{<}73997276754{^}{>}55" : [[7, 8, 2],[4, 9],[7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5],[6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2,]],
            # r"{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}" : [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []],
            # r"{_}6" : [[], [6]],
            # r"{}" : [],
            # r"{^}{^}{^}{^}{^}{^}" : [],
            }

for test in small_test_list:
    print(f"Test: {test}")
    print(f"Expected: {small_test_list[test]}")
    print(f"Result: {decoder(test)}")
    print(len(decoder(test)), len(small_test_list[test]))
    print(f"Passed: {decoder(test) == small_test_list[test]}")
    print()
# Out:
# Test: {^}58
# Expected: []
# Result: [[5, 8]]
# 1 0
# Passed: False

# %%
def decoder(test):
    # Remove brackets
    test = test.replace('{', '').replace('}', '')

    # Ignore consecutive '^' commands at the beginning
    while test and test[0] == '^':
        test = test[1:]

    if test == "":
        return []

    matrix = {0: []}
    cursor_index = [0, 0]
    cursor_positions = {0: 0}

    for i in test:
        if i == '_':
            cursor_index[0] += 1
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_positions[cursor_index[0]] = cursor_positions.get(cursor_index[0], 0)
            cursor_index[1] = cursor_positions[cursor_index[0]]
        elif i == '^':
            cursor_index[0] = max(0, cursor_index[0] - 1)
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = min(cursor_positions[cursor_index[0]], cursor_positions.get(cursor_index[0] + 1, 0))
            cursor_positions[cursor_index[0]] = cursor_index[1]
        elif i == '>':
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1] + 1)
            cursor_positions[cursor_index[0]] = cursor_index[1]
        elif i == '<':
            cursor_index[1] = max(0, cursor_index[1] - 1)
            cursor_positions[cursor_index[0]] = cursor_index[1]
        elif i.isdigit():
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            matrix[cursor_index[0]].insert(cursor_index[1], int(i))
            cursor_index[1] += 1
            cursor_positions[cursor_index[0]] = cursor_index[1]
    result = []

    if len(matrix) == 1:
        return matrix[0]

    for n in range(len(matrix)):
        result.append(matrix.get(n, []))
    return result





small_test_list = {
            r"2618{_}97{^}{<}4552" : [[2,6,1,8,4,5,5,2],[9,7]],
            r"{<}{^}61{_}{^}285316{<}{^}62633487{<}{<}2{>}{<}8" : [[6,1,2,8,5,3,1,6,2,6,3,3,4,2,8,8,7,6],[]],
            r"123" : [1,2,3],
            r"1{>}2{_}3{>}4{<}5{>}6{<}7{>}8{<}9" : [[1,2],[3,5,4,7,6,9,8]],
            r"{>}78{_}49{<}{^}{>}2{_}{_}789879626{<}7{>}{_}{<}{<}67581332{<}73997276754{^}{>}55" : [[7, 8, 2],[4, 9],[7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5],[6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2,]],
            r"{_}6" : [[], [6]],
            r"{}" : [],
            r"{^}{^}{^}{^}{^}{^}" : [],
            r"{_}{_}{_}{_}{_}{_}" : [[], [], [], [], [], [], []],
            r"{<}{<}{<}{<}" : [],
            r"{>}{>}{>}{>}" : [],
            r"{_}162{_}5{_}4" : [[], [1, 6, 2], [5], [4]],
            r"{>}6{>}{<}{<}87{>}" : [8, 7, 6],
            r"{>}{<}{_}{<}{<}{^}{^}{^}{^}{_}" : [[], []],
            }

for test in small_test_list:
    print(f"Test: {test}")
    print(f"Expected: {small_test_list[test]}")
    print(f"Result: {decoder(test)}")
    print(len(decoder(test)), len(small_test_list[test]))
    print(f"Passed: {decoder(test) == small_test_list[test]}")
    # print()
# Out:
# Test: 2618{_}97{^}{<}4552
# Expected: [[2, 6, 1, 8, 4, 5, 5, 2], [9, 7]]
# Result: [[2, 4, 5, 5, 2, 6, 1, 8], [9, 7]]
# 2 2
# Passed: False
# Test: {<}{^}61{_}{^}285316{<}{^}62633487{<}{<}2{>}{<}8
# Expected: [[6, 1, 2, 8, 5, 3, 1, 6, 2, 6, 3, 3, 4, 2, 8, 8, 7, 6], []]
# Result: [[6, 2, 6, 3, 3, 4, 2, 8, 8, 7, 2, 8, 5, 3, 1, 6, 6, 1], []]
# 2 2
# Passed: False
# Test: 123
# Expected: [1, 2, 3]
# Result: [1, 2, 3]
# 3 3
# Passed: True
# Test: 1{>}2{_}3{>}4{<}5{>}6{<}7{>}8{<}9
# Expected: [[1, 2], [3, 5, 4, 7, 6, 9, 8]]
# Result: [[1, 2], [3, 5, 4, 7, 6, 9, 8]]
# 2 2
# Passed: True
# Test: {>}78{_}49{<}{^}{>}2{_}{_}789879626{<}7{>}{_}{<}{<}67581332{<}73997276754{^}{>}55
# Expected: [[7, 8, 2], [4, 9], [7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5], [6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2]]
# Result: [[7, 8, 2], [4, 9], [7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5], [6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2]]
# 4 4
# Passed: True
# Test: {_}6
# Expected: [[], [6]]
# Result: [[], [6]]
# 2 2
# Passed: True
# Test: {}
# Expected: []
# Result: []
# 0 0
# Passed: True
# Test: {^}{^}{^}{^}{^}{^}
# Expected: []
# Result: []
# 0 0
# Passed: True
# Test: {_}{_}{_}{_}{_}{_}
# Expected: [[], [], [], [], [], [], []]
# Result: [[], [], [], [], [], [], []]
# 7 7
# Passed: True
# Test: {<}{<}{<}{<}
# Expected: []
# Result: []
# 0 0
# Passed: True
# Test: {>}{>}{>}{>}
# Expected: []
# Result: []
# 0 0
# Passed: True
# Test: {_}162{_}5{_}4
# Expected: [[], [1, 6, 2], [5], [4]]
# Result: [[], [1, 6, 2], [5], [4]]
# 4 4
# Passed: True
# Test: {>}6{>}{<}{<}87{>}
# Expected: [8, 7, 6]
# Result: [8, 7, 6]
# 3 3
# Passed: True
# Test: {>}{<}{_}{<}{<}{^}{^}{^}{^}{_}
# Expected: [[], []]
# Result: [[], []]
# 2 2
# Passed: True

# %%
# Leonardo Azzi, Soluzione v1:
# FINAL SOLUTION

def decoder(test):
    # Remove brackets
    test = test.replace('{', '').replace('}', '')

    # Ignore consecutive '^' commands at the beginning
    while test and test[0] == '^':
        test = test[1:]
        
    if test == "":
        return []
    
    matrix = {0: []}
    cursor_index = [0, 0]
    
        
    for i in test:
        if i == '_':
            cursor_index[0] += 1
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1])
        elif i == '^':
            cursor_index[0] = max(0, cursor_index[0] - 1)
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = len(matrix.get(cursor_index[0], [])) + 1
        elif i == '>':
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1] + 1)
        elif i == '<':
            cursor_index[1] = max(0, cursor_index[1] - 1)
        elif i.isdigit():
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            matrix[cursor_index[0]].insert(cursor_index[1], int(i))
            cursor_index[1] += 1
    result = []
    
    if len(matrix) == 1:
        return matrix[0]
    
    for n in range(len(matrix)):
        result.append(matrix.get(n, []))
    return result



small_test_list = {
            r"2618{_}97{^}{<}4552" : [[2,6,1,4,5,5,2,8],[9,7]],
            r"{<}{^}61{_}{^}285316{<}{^}62633487{<}{<}2{>}{<}8" : [[6,1,2,8,5,3,1,6,2,6,3,3,4,2,8,8,7,6],[]],
            r"57{<}{>}17{>}95{<}3{<}{<}24" : [5,7,1,7,2,4,9,3,5],
            r"123" : [1,2,3],
            r"1{>}2{_}3{>}4{<}5{>}6{<}7{>}8{<}9" : [[1,2],[3,5,4,7,6,9,8]],
            r"{>}78{_}49{<}{^}{>}2{_}{_}789879626{<}7{>}{_}{<}{<}67581332{<}73997276754{^}{>}55" : [[7, 8, 2],[4, 9],[7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5],[6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2,]],
            r"{_}6" : [[], [6]],
            r"{}" : [],
            r"{^}{^}{^}{^}{^}{^}" : [],
            r"{_}{_}{_}{_}{_}{_}" : [[], [], [], [], [], [], []],
            r"{<}{<}{<}{<}" : [],
            r"{>}{>}{>}{>}" : [],
            r"{_}162{_}5{_}4" : [[], [1, 6, 2], [5], [4]],
            r"{>}6{>}{<}{<}87{>}" : [8, 7, 6],
            r"{>}{<}{_}{<}{<}{^}{^}{^}{^}{_}" : [[], []],
            }

for test in small_test_list:
    print(f"Test: {test}")
    print(f"Expected: {small_test_list[test]}")
    print(f"Result: {decoder(test)}")
    # print(len(decoder(test)), len(small_test_list[test]))
    print(f"Passed: {decoder(test) == small_test_list[test]}")
    print()
# Out:
# Test: 2618{_}97{^}{<}4552
# Expected: [[2, 6, 1, 4, 5, 5, 2, 8], [9, 7]]
# Result: [[2, 6, 1, 8, 4, 5, 5, 2], [9, 7]]
# Passed: False
#
# Test: {<}{^}61{_}{^}285316{<}{^}62633487{<}{<}2{>}{<}8
# Expected: [[6, 1, 2, 8, 5, 3, 1, 6, 2, 6, 3, 3, 4, 2, 8, 8, 7, 6], []]
# Result: [[6, 1, 2, 8, 5, 3, 1, 6, 6, 2, 6, 3, 3, 4, 8, 2, 8, 7], []]
# Passed: False
#
# Test: 57{<}{>}17{>}95{<}3{<}{<}24
# Expected: [5, 7, 1, 7, 2, 4, 9, 3, 5]
# Result: [5, 7, 1, 7, 2, 4, 9, 3, 5]
# Passed: True
#
# Test: 123
# Expected: [1, 2, 3]
# Result: [1, 2, 3]
# Passed: True
#
# Test: 1{>}2{_}3{>}4{<}5{>}6{<}7{>}8{<}9
# Expected: [[1, 2], [3, 5, 4, 7, 6, 9, 8]]
# Result: [[1, 2], [3, 5, 4, 7, 6, 9, 8]]
# Passed: True
#
# Test: {>}78{_}49{<}{^}{>}2{_}{_}789879626{<}7{>}{_}{<}{<}67581332{<}73997276754{^}{>}55
# Expected: [[7, 8, 2], [4, 9], [7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5], [6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2]]
# Result: [[7, 8, 2], [4, 9], [7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5], [6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2]]
# Passed: True
#
# Test: {_}6
# Expected: [[], [6]]
# Result: [[], [6]]
# Passed: True
#
# Test: {}
# Expected: []
# Result: []
# Passed: True
#
# Test: {^}{^}{^}{^}{^}{^}
# Expected: []
# Result: []
# Passed: True
#
# Test: {_}{_}{_}{_}{_}{_}
# Expected: [[], [], [], [], [], [], []]
# Result: [[], [], [], [], [], [], []]
# Passed: True
#
# Test: {<}{<}{<}{<}
# Expected: []
# Result: []
# Passed: True
#
# Test: {>}{>}{>}{>}
# Expected: []
# Result: []
# Passed: True
#
# Test: {_}162{_}5{_}4
# Expected: [[], [1, 6, 2], [5], [4]]
# Result: [[], [1, 6, 2], [5], [4]]
# Passed: True
#
# Test: {>}6{>}{<}{<}87{>}
# Expected: [8, 7, 6]
# Result: [8, 7, 6]
# Passed: True
#
# Test: {>}{<}{_}{<}{<}{^}{^}{^}{^}{_}
# Expected: [[], []]
# Result: [[], []]
# Passed: True

# %%
# Leonardo Azzi, Soluzione v1:
# FINAL SOLUTION

def decoder(test):
    # Remove brackets
    test = test.replace('{', '').replace('}', '')

    # Ignore consecutive '^' commands at the beginning
    while test and test[0] == '^':
        test = test[1:]

    if test == "":
        return []

    matrix = {0: []}
    cursor_index = [0, 0]

    for i in test:
        if i == '_':
            cursor_index[0] += 1
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1])
        elif i == '^':
            if cursor_index[0] == 0:
                continue
            cursor_index[0] = max(0, cursor_index[0] - 1)
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = len(matrix.get(cursor_index[0], []))
        elif i == '>':
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1] + 1)
        elif i == '<':
            cursor_index[1] = max(0, cursor_index[1] - 1)
        elif i.isdigit():
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            matrix[cursor_index[0]].insert(cursor_index[1], int(i))
            cursor_index[1] += 1
    result = []

    if len(matrix) == 1:
        return matrix[0]

    for n in range(len(matrix)):
        result.append(matrix.get(n, []))
    return result

        # elif i == '^':
        #     cursor_index[0] = max(0, cursor_index[0] - 1)
        #     matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
        #     cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1])


small_test_list = {
            r"2618{_}97{^}{<}4552" : [[2,6,1,4,5,5,2,8],[9,7]],
            r"2618{_}97{^}{<}4552" : [[2,6,1,8],[9,7]],
            r"{<}{^}61{_}{^}285316{<}{^}62633487{<}{<}2{>}{<}8" : [[6,1,2,8,5,3,1,6,2,6,3,3,4,2,8,8,7,6],[]],
            r"57{<}{>}17{>}95{<}3{<}{<}24" : [5,7,1,7,2,4,9,3,5],
            r"123" : [1,2,3],
            r"1{>}2{_}3{>}4{<}5{>}6{<}7{>}8{<}9" : [[1,2],[3,5,4,7,6,9,8]],
            r"{>}78{_}49{<}{^}{>}2{_}{_}789879626{<}7{>}{_}{<}{<}67581332{<}73997276754{^}{>}55" : [[7, 8, 2],[4, 9],[7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5],[6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2,]],
            r"{_}6" : [[], [6]],
            r"{}" : [],
            r"{^}{^}{^}{^}{^}{^}" : [],
            r"{_}{_}{_}{_}{_}{_}" : [[], [], [], [], [], [], []],
            r"{<}{<}{<}{<}" : [],
            r"{>}{>}{>}{>}" : [],
            r"{_}162{_}5{_}4" : [[], [1, 6, 2], [5], [4]],
            r"{>}6{>}{<}{<}87{>}" : [8, 7, 6],
            r"{>}{<}{_}{<}{<}{^}{^}{^}{^}{_}" : [[], []],
            }

for test in small_test_list:
    print(f"Test: {test}")
    print(f"Expected: {small_test_list[test]}")
    print(f"Result: {decoder(test)}")
    # print(len(decoder(test)), len(small_test_list[test]))
    print(f"Passed: {decoder(test) == small_test_list[test]}")
    print()
# Out:
# Test: 2618{_}97{^}{<}4552
# Expected: [[2, 6, 1, 4, 5, 5, 2, 8], [9, 7]]
# Result: [[2, 6, 1, 4, 5, 5, 2, 8], [9, 7]]
# Passed: True
#
# Test: {<}{^}61{_}{^}285316{<}{^}62633487{<}{<}2{>}{<}8
# Expected: [[6, 1, 2, 8, 5, 3, 1, 6, 2, 6, 3, 3, 4, 2, 8, 8, 7, 6], []]
# Result: [[6, 1, 2, 8, 5, 3, 1, 6, 2, 6, 3, 3, 4, 2, 8, 8, 7, 6], []]
# Passed: True
#
# Test: 57{<}{>}17{>}95{<}3{<}{<}24
# Expected: [5, 7, 1, 7, 2, 4, 9, 3, 5]
# Result: [5, 7, 1, 7, 2, 4, 9, 3, 5]
# Passed: True
#
# Test: 123
# Expected: [1, 2, 3]
# Result: [1, 2, 3]
# Passed: True
#
# Test: 1{>}2{_}3{>}4{<}5{>}6{<}7{>}8{<}9
# Expected: [[1, 2], [3, 5, 4, 7, 6, 9, 8]]
# Result: [[1, 2], [3, 5, 4, 7, 6, 9, 8]]
# Passed: True
#
# Test: {>}78{_}49{<}{^}{>}2{_}{_}789879626{<}7{>}{_}{<}{<}67581332{<}73997276754{^}{>}55
# Expected: [[7, 8, 2], [4, 9], [7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5], [6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2]]
# Result: [[7, 8, 2], [4, 9], [7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5], [6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2]]
# Passed: True
#
# Test: {_}6
# Expected: [[], [6]]
# Result: [[], [6]]
# Passed: True
#
# Test: {}
# Expected: []
# Result: []
# Passed: True
#
# Test: {^}{^}{^}{^}{^}{^}
# Expected: []
# Result: []
# Passed: True
#
# Test: {_}{_}{_}{_}{_}{_}
# Expected: [[], [], [], [], [], [], []]
# Result: [[], [], [], [], [], [], []]
# Passed: True
#
# Test: {<}{<}{<}{<}
# Expected: []
# Result: []
# Passed: True
#
# Test: {>}{>}{>}{>}
# Expected: []
# Result: []
# Passed: True
#
# Test: {_}162{_}5{_}4
# Expected: [[], [1, 6, 2], [5], [4]]
# Result: [[], [1, 6, 2], [5], [4]]
# Passed: True
#
# Test: {>}6{>}{<}{<}87{>}
# Expected: [8, 7, 6]
# Result: [8, 7, 6]
# Passed: True
#
# Test: {>}{<}{_}{<}{<}{^}{^}{^}{^}{_}
# Expected: [[], []]
# Result: [[], []]
# Passed: True

# %%
T = int(input()) # numero di casi di test

def decoder(test):
    matrix = {}
    cursor_index = [0, 0]
    for i in test:
        if i == '{' or i == '}':
            continue
        elif i == '_':
            cursor_index[0] = cursor_index[0] + 1
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = min(len(matrix[cursor_index[0]]), cursor_index[1])
            #Se necessario, implementare un cap massimo di "profondità" (usa min(max_depth, cursor_index[0] + 1))
        elif i == '^':
            cursor_index[0] = max(0, cursor_index[0] - 1)
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = min(len(matrix[cursor_index[0]]), cursor_index[1])
        elif i == '>':
            cursor_index[1] = min(len(matrix[cursor_index[0]]), cursor_index[1] + 1)
        elif i == '<':
            cursor_index[1] = max(0, cursor_index[1] - 1)
        elif i.isdigit():
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            matrix[cursor_index[0]].insert(cursor_index[1], int(i))
            cursor_index[1] += 1
    result = []
    for n in range(len(matrix)):
        result.append(matrix[n])
    return result

for t in range(T):
    input() # spazio
    test = input()
    print(f"Case #{t+1}: {decoder(test)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 T = int(input()) # numero di casi di test
#       3 def decoder(test):
#       4     matrix = {}
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Leonardo Azzi, Soluzione v1:
# Possible changes:
#   import blist?
#   use a list of lists instead of a dict?  (dict is faster, but list is more memory efficient)

def decoder(test):
    matrix = {}
    cursor_index = [0, 0]
    for i in test:
        if i == '{' or i == '}':
            continue
        elif i == '_':
            cursor_index[0] = cursor_index[0] + 1
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1])
            #Se necessario, implementare un cap massimo di "profondità" (usa min(max_depth, cursor_index[0] + 1))
        elif i == '^':
            cursor_index[0] = max(0, cursor_index[0] - 1)
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1])
        elif i == '>':
            cursor_index[1] = min(len(matrix.get(cursor_index[0], [])), cursor_index[1] + 1)
        elif i == '<':
            cursor_index[1] = max(0, cursor_index[1] - 1)
            #print(f"Cursor index: {cursor_index[1]}")
        elif i.isdigit():
            matrix[cursor_index[0]] = matrix.get(cursor_index[0], [])
            matrix[cursor_index[0]].insert(cursor_index[1], int(i))
            cursor_index[1] += 1
            #print(matrix)
    result = []
    for n in range(len(matrix)):
        result.append(matrix[n])
    return result

small_test_list = {
            # r"1{>}2{_}3{>}4{<}5{>}6{<}7{>}8{<}9" : [[1,2],[3,5,4,7,6,9,8]],
            # r"1{>}23{_}4{>}56{_}7{>}89" : [[1, 2, 3], [4, 5, 6], [7, 8, 9]],
            # r"1{_}23{^}4{_}56{^}7{_}89" : [[1, 4, 7], [2, 3, 5, 8, 9, 6]],
            # r"1{>}2{>}3{<}{_}4{>}5{>}6{<}{_}7{>}8{>}9" : [[1, 2, 3], [4, 5, 6], [7, 8, 9]],
            # r"{>}78{_}49{<}{^}{>}2{_}{_}789879626{<}7{>}{_}{<}{<}67581332{<}73997276754{^}{>}55" : [[7, 8, 2],[4, 9],[7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5],[6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2,]],
            }

for test in small_test_list:
    print(f"Test: {test}")
    print(f"Expected: {small_test_list[test]}")
    print(f"Result: {decoder(test)}")
    print(f"Passed: {decoder(test) == small_test_list[test]}")
    print()

# %%
small_test_list = {
            # r"1{>}2{_}3{>}4{<}5{>}6{<}7{>}8{<}9" : [[1,2],[3,5,4,7,6,9,8]],
            # r"1{>}23{_}4{>}56{_}7{>}89" : [[1, 2, 3], [4, 5, 6], [7, 8, 9]],
            # r"1{_}23{^}4{_}56{^}7{_}89" : [[1, 4, 7], [2, 3, 5, 8, 9, 6]],
            # r"1{>}2{>}3{<}{_}4{>}5{>}6{<}{_}7{>}8{>}9" : [[1, 2, 3], [4, 5, 6], [7, 8, 9]],
            r"{>}78{_}49{<}{^}{>}2{_}{_}789879626{<}7{>}{_}{<}{<}67581332{<}73997276754{^}{>}55" : [[7, 8, 2],[4, 9],[7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5],[6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2,]],
            }

for test in small_test_list:
    print(f"Test: {test}")
    print(f"Expected: {small_test_list[test]}")
    print(f"Result: {decoder(test)}")
    print(f"Passed: {decoder(test) == small_test_list[test]}")
    print()
# Out:
# Test: {>}78{_}49{<}{^}{>}2{_}{_}789879626{<}7{>}{_}{<}{<}67581332{<}73997276754{^}{>}55
# Expected: [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# Result: [[7, 8, 2], [4, 9], [7, 8, 9, 8, 7, 9, 6, 2, 7, 6, 5, 5], [6, 7, 5, 8, 1, 3, 3, 7, 3, 9, 9, 7, 2, 7, 6, 7, 5, 4, 2]]
# Passed: False

# %%
s = r"{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}{_}"
s = s.replace("{", "").replace("}", "")
print(len(s))
print([[] for x in range(96)])
# Out:
# 95
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]

# %%
# In order, the following tests passed/Failed:

# Passed: True

# Passed: True

# Passed: True

# Passed: True

# Passed: True

# Passed: False

# Passed: True

# Passed: True

# Passed: False
# In particolare, l'indice di colonna dopo il comando {^} dovrà essere uguale al minimo tra la lunghezza della riga a cui si sta salendo e l'attuale indice di colonna del cursore.

# [[4, 4, 4], [7, 4, 2, 1, 2, 6, 8, 9, 7, 4, 9, 7], [9, 5, 5, 7, 9, 8]]
# _ = r"4{_}{<}7{^}{_}{>}4{^}44{_}21297497{_}95578{<}{^}{_}9{>}{^}{<}68"
# [[4,4,4],[7,4,2,1,2,9,7,4,9,7],[9,5,5,7,9,8]]

# "4{_}{<}7{^}{_}{>}4{^}44"
# [[4,4,4],[7,4]]

# _ = r"4{_}{<}7{^}{_}{>}4{^}44{_}21297497{_}95578"
# [[4,4,4],[7,4,2,1,2,9,7,4,9,7],[9,5,5,7,8]]

# _ = r"4{_}{<}7{^}{_}{>}4{^}44{_}21297497{_}95578{<}{^}{_}9{>}{^}{<}68"
# [[4,4,4],[7,4,2,1,2,9,7,4,9,7],[9,5,5,7,8]]
# [[4,4,4],[7,4,2,1,6,8,2,9,7,4,9,7],[9,5,5,7,8,9]]
